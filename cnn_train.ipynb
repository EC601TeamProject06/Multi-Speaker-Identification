# %%
import os
import shutil
import numpy as np

import tensorflow as tf
import tensorflow_io as tfio
from tensorflow import keras
from tensorflow import lite

from pathlib import Path
from IPython.display import display, Audio

# Get the data from https://www.kaggle.com/kongaevans/speaker-recognition-dataset/download
# and save it to the 'Downloads' folder in your HOME directory
DATASET_ROOT = os.path.join(os.path.expanduser("~"), "Documents/EC601/term-project/Multi-Speaker-Identification/user-recordings")

# The folders in which we will put the audio samples and the noise samples
AUDIO_SUBFOLDER = "audio"
NOISE_SUBFOLDER = "noise"

DATASET_AUDIO_PATH = os.path.join(DATASET_ROOT, AUDIO_SUBFOLDER)
DATASET_NOISE_PATH = os.path.join(DATASET_ROOT, NOISE_SUBFOLDER)

# Percentage of samples to use for validation
VALID_SPLIT = 0.1

# Seed to use when shuffling the dataset and the noise
SHUFFLE_SEED = 43

# The sampling rate to use.
# This is the one used in all of the audio samples.
# We will resample all of the noise to this sampling rate.
# This will also be the output size of the audio wave samples
# (since all samples are of 1 second long)
SAMPLING_RATE = 16000

# The factor to multiply the noise with according to:
#   noisy_sample = sample + noise * prop * scale
#      where prop = sample_amplitude / noise_amplitude
SCALE = 0.5

BATCH_SIZE = 128
EPOCHS = 100

# %%
# If folder `audio`, does not exist, create it, otherwise do nothing
if os.path.exists(DATASET_AUDIO_PATH) is False:
    os.makedirs(DATASET_AUDIO_PATH)

# If folder `noise`, does not exist, create it, otherwise do nothing
if os.path.exists(DATASET_NOISE_PATH) is False:
    os.makedirs(DATASET_NOISE_PATH)

for folder in os.listdir(DATASET_ROOT):
    if os.path.isdir(os.path.join(DATASET_ROOT, folder)):
        if folder in [AUDIO_SUBFOLDER, NOISE_SUBFOLDER]:
            # If folder is `audio` or `noise`, do nothing
            continue
        elif folder in ["other", "_background_noise_"]:
            # If folder is one of the folders that contains noise samples,
            # move it to the `noise` folder
            shutil.move(
                os.path.join(DATASET_ROOT, folder),
                os.path.join(DATASET_NOISE_PATH, folder),
            )
        else:
            # Otherwise, it should be a speaker folder, then move it to
            # `audio` folder
            shutil.move(
                os.path.join(DATASET_ROOT, folder),
                os.path.join(DATASET_AUDIO_PATH, folder),
            )

# %%
# Get the list of all noise files
noise_paths = []
for subdir in os.listdir(DATASET_NOISE_PATH):
    subdir_path = Path(DATASET_NOISE_PATH) / subdir
    if os.path.isdir(subdir_path):
        noise_paths += [
            os.path.join(subdir_path, filepath)
            for filepath in os.listdir(subdir_path)
            if filepath.endswith(".wav")
        ]

print(
    "Found {} files belonging to {} directories".format(
        len(noise_paths), len(os.listdir(DATASET_NOISE_PATH))
    )
)
# Out:
# Found 6 files belonging to 2 directories

# %%
command = (
    "for dir in `ls -1 " + DATASET_NOISE_PATH + "`; do "
    "for file in `ls -1 " + DATASET_NOISE_PATH + "/$dir/*.wav`; do "
    "sample_rate=`ffprobe -hide_banner -loglevel panic -show_streams "
    "$file | grep sample_rate | cut -f2 -d=`; "
    "if [ $sample_rate -ne 16000 ]; then "
    "ffmpeg -hide_banner -loglevel panic -y "
    "-i $file -ar 16000 temp.wav; "
    "mv temp.wav $file; "
    "fi; done; done"
)

os.system(command)

# Split noise into chunks of 16000 each
def load_noise_sample(path):
    sample, sampling_rate = tf.audio.decode_wav(
        tf.io.read_file(path), desired_channels=1
    )
    print(sampling_rate)
    if sampling_rate == SAMPLING_RATE:
        # Number of slices of 16000 each that can be generated from the noise sample
        slices = int(sample.shape[0] / SAMPLING_RATE)
        sample = tf.split(sample[: slices * SAMPLING_RATE], slices)
        return sample
    else:
        print("Sampling rate for {} is incorrect. Ignoring it".format(path))
        return None


noises = []
for path in noise_paths:
    sample = load_noise_sample(path)
    if sample:
        noises.extend(sample)
noises = tf.stack(noises)

print(
    "{} noise files were split into {} noise samples where each is {} sec. long".format(
        len(noise_paths), noises.shape[0], noises.shape[1] // SAMPLING_RATE
    )
)
# Out:
# tf.Tensor(16000, shape=(), dtype=int32)
# tf.Tensor(16000, shape=(), dtype=int32)
# tf.Tensor(16000, shape=(), dtype=int32)
# tf.Tensor(16000, shape=(), dtype=int32)
# tf.Tensor(16000, shape=(), dtype=int32)
# tf.Tensor(16000, shape=(), dtype=int32)
# 6 noise files were split into 354 noise samples where each is 1 sec. long

# %%
def paths_and_labels_to_dataset(audio_paths, labels):
    """Constructs a dataset of audios and labels."""
    path_ds = tf.data.Dataset.from_tensor_slices(audio_paths)
    audio_ds = path_ds.map(lambda x: path_to_audio(x))
    label_ds = tf.data.Dataset.from_tensor_slices(labels)
    return tf.data.Dataset.zip((audio_ds, label_ds))


def path_to_audio(path):
    """Reads and decodes an audio file."""
    audio = tf.io.read_file(path)
    audio, _ = tf.audio.decode_wav(audio, 1, SAMPLING_RATE)
    return audio


def add_noise(audio, noises=None, scale=0.5):
    if noises is not None:
        # Create a random tensor of the same size as audio ranging from
        # 0 to the number of noise stream samples that we have.
        tf_rnd = tf.random.uniform(
            (tf.shape(audio)[0],), 0, noises.shape[0], dtype=tf.int32
        )
        noise = tf.gather(noises, tf_rnd, axis=0)

        # Get the amplitude proportion between the audio and the noise
        prop = tf.math.reduce_max(audio, axis=1) / tf.math.reduce_max(noise, axis=1)
        prop = tf.repeat(tf.expand_dims(prop, axis=1), tf.shape(audio)[1], axis=1)

        # Adding the rescaled noise to audio
        audio = audio + noise * prop * scale

    return audio


def audio_to_fft(audio):
    # Since tf.signal.fft applies FFT on the innermost dimension,
    # we need to squeeze the dimensions and then expand them again
    # after FFT
    audio = tf.squeeze(audio, axis=-1)
    fft = tf.signal.fft(
        tf.cast(tf.complex(real=audio, imag=tf.zeros_like(audio)), tf.complex64)
    )
    fft = tf.expand_dims(fft, axis=-1)

    # Return the absolute value of the first half of the FFT
    # which represents the positive frequencies
    return tf.math.abs(fft[:, : (audio.shape[1] // 2), :])


# Get the list of audio file paths along with their corresponding labels

class_names = os.listdir(DATASET_AUDIO_PATH)
print("Our class names: {}".format(class_names,))

audio_paths = []
labels = []
for label, name in enumerate(class_names):
    print(label)
    print("Processing speaker {}".format(name,))
    dir_path = Path(DATASET_AUDIO_PATH) / name
    speaker_sample_paths = [
        os.path.join(dir_path, filepath)
        for filepath in os.listdir(dir_path)
        if filepath.endswith(".wav")
    ]
    audio_paths += speaker_sample_paths
    labels += [label] * len(speaker_sample_paths)

print(
    "Found {} files belonging to {} classes.".format(len(audio_paths), len(class_names))
)

# Shuffle
rng = np.random.RandomState(SHUFFLE_SEED)
rng.shuffle(audio_paths)
rng = np.random.RandomState(SHUFFLE_SEED)
rng.shuffle(labels)

# Split into training and validation
num_val_samples = int(VALID_SPLIT * len(audio_paths))
print("Using {} files for training.".format(len(audio_paths) - num_val_samples))
train_audio_paths = audio_paths[:-num_val_samples]
train_labels = labels[:-num_val_samples]

print("Using {} files for validation.".format(num_val_samples))
valid_audio_paths = audio_paths[-num_val_samples:]
valid_labels = labels[-num_val_samples:]

# Create 2 datasets, one for training and the other for validation
train_ds = paths_and_labels_to_dataset(train_audio_paths, train_labels)
train_ds = train_ds.shuffle(buffer_size=BATCH_SIZE * 8, seed=SHUFFLE_SEED).batch(
    BATCH_SIZE
)

valid_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
valid_ds = valid_ds.shuffle(buffer_size=32 * 8, seed=SHUFFLE_SEED).batch(32)


# Add noise to the training set
train_ds = train_ds.map(
    lambda x, y: (add_noise(x, noises, scale=SCALE), y),
    num_parallel_calls=tf.data.experimental.AUTOTUNE,
)

# Transform audio wave to the frequency domain using `audio_to_fft`
train_ds = train_ds.map(
    lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.experimental.AUTOTUNE
)
train_ds = train_ds.prefetch(tf.data.experimental.AUTOTUNE)

valid_ds = valid_ds.map(
    lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.experimental.AUTOTUNE
)
valid_ds = valid_ds.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# Our class names: ['Hubert', 'Yuhan']
# 0
# Processing speaker Hubert
# 1
# Processing speaker Yuhan
# Found 315 files belonging to 2 classes.
# Using 284 files for training.
# Using 31 files for validation.
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x000001C3AAF1C700> and will run it as-is.
# Cause: could not parse the source code:
#
#     lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.experimental.AUTOTUNE
#
# This error may be avoided by creating the lambda in a standalone statement.
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x000001C3AAF1C700> and will run it as-is.
# Cause: could not parse the source code:
#
#     lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.experimental.AUTOTUNE
#
# This error may be avoided by creating the lambda in a standalone statement.
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x000001C3AAF1C3A0> and will run it as-is.
# Cause: could not parse the source code:
#
#     lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.experimental.AUTOTUNE
#
# This error may be avoided by creating the lambda in a standalone statement.
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x000001C3AAF1C3A0> and will run it as-is.
# Cause: could not parse the source code:
#
#     lambda x, y: (audio_to_fft(x), y), num_parallel_calls=tf.data.experimental.AUTOTUNE
#
# This error may be avoided by creating the lambda in a standalone statement.
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
def residual_block(x, filters, conv_num=3, activation="relu"):
    # Shortcut
    s = keras.layers.Conv1D(filters, 1, padding="same")(x)
    for i in range(conv_num - 1):
        x = keras.layers.Conv1D(filters, 3, padding="same")(x)
        x = keras.layers.Activation(activation)(x)
    x = keras.layers.Conv1D(filters, 3, padding="same")(x)
    x = keras.layers.Add()([x, s])
    x = keras.layers.Activation(activation)(x)
    return keras.layers.MaxPool1D(pool_size=2, strides=2)(x)


def build_model(input_shape, num_classes):
    inputs = keras.layers.Input(shape=input_shape, name="input")

    x = residual_block(inputs, 16, 2)
    x = residual_block(x, 32, 2)
    x = residual_block(x, 64, 3)
    x = residual_block(x, 128, 3)
    x = residual_block(x, 128, 3)

    x = keras.layers.AveragePooling1D(pool_size=3, strides=3)(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Dense(256, activation="relu")(x)
    x = keras.layers.Dense(128, activation="relu")(x)

    outputs = keras.layers.Dense(num_classes, activation="softmax", name="output")(x)

    return keras.models.Model(inputs=inputs, outputs=outputs)


model = build_model((SAMPLING_RATE // 2, 1), len(class_names))

model.summary()

# Compile the model using Adam's default learning rate
model.compile(
    optimizer="Adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)

# Add callbacks:
# 'EarlyStopping' to stop training when the model is not enhancing anymore
# 'ModelCheckPoint' to always keep the model that has the best val_accuracy
model_save_filename = "user_model.h5"

earlystopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
mdlcheckpoint_cb = keras.callbacks.ModelCheckpoint(
    model_save_filename, monitor="val_accuracy", save_best_only=True
)
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 8000, 1)]    0
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 8000, 16)     64          input[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8000, 16)     0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 8000, 16)     784         activation_13[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 8000, 16)     32          input[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8000, 16)     0           conv1d_20[0][0]
#                                                                  conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8000, 16)     0           add_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 4000, 16)     0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 4000, 32)     1568        max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4000, 32)     0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 4000, 32)     3104        activation_15[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 4000, 32)     544         max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4000, 32)     0           conv1d_23[0][0]
#                                                                  conv1d_21[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4000, 32)     0           add_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 2000, 32)     0           activation_16[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 2000, 64)     6208        max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 2000, 64)     0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 2000, 64)     12352       activation_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 2000, 64)     0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 2000, 64)     12352       activation_18[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 2000, 64)     2112        max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 2000, 64)     0           conv1d_27[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 2000, 64)     0           add_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 1000, 64)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 1000, 128)    24704       max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 1000, 128)    0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 1000, 128)    49280       activation_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 1000, 128)    0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 1000, 128)    49280       activation_21[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 1000, 128)    8320        max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 1000, 128)    0           conv1d_31[0][0]
#                                                                  conv1d_28[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 1000, 128)    0           add_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 500, 128)     0           activation_22[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 500, 128)     49280       max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 500, 128)     0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 500, 128)     49280       activation_23[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 500, 128)     0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 500, 128)     49280       activation_24[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 500, 128)     16512       max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 500, 128)     0           conv1d_35[0][0]
#                                                                  conv1d_32[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 500, 128)     0           add_9[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_9 (MaxPooling1D)  (None, 250, 128)     0           activation_25[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_1 (AveragePoo (None, 83, 128)      0           max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 10624)        0           average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          2720000     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          32896       dense_2[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 2)            258         dense_3[0][0]
# ==================================================================================================
# Total params: 3,088,210
# Trainable params: 3,088,210
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    validation_data=valid_ds,
    callbacks=[earlystopping_cb, mdlcheckpoint_cb],
)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 2s 732ms/step - loss: 1.9212 - accuracy: 0.5070 - val_loss: 0.8233 - val_accuracy: 0.6129
# Epoch 2/100
# 3/3 [==============================] - 2s 628ms/step - loss: 1.0862 - accuracy: 0.4824 - val_loss: 0.6206 - val_accuracy: 0.4194
# Epoch 3/100
# 3/3 [==============================] - 2s 629ms/step - loss: 0.5551 - accuracy: 0.6162 - val_loss: 0.5645 - val_accuracy: 0.4194
# Epoch 4/100
# 3/3 [==============================] - 2s 652ms/step - loss: 0.4422 - accuracy: 0.7254 - val_loss: 0.3479 - val_accuracy: 0.9032
# Epoch 5/100
# 3/3 [==============================] - 2s 629ms/step - loss: 0.2149 - accuracy: 0.9683 - val_loss: 0.0929 - val_accuracy: 0.9032
# Epoch 6/100
# 3/3 [==============================] - 2s 657ms/step - loss: 0.1952 - accuracy: 0.9401 - val_loss: 0.0636 - val_accuracy: 1.0000
# Epoch 7/100
# 3/3 [==============================] - 2s 627ms/step - loss: 0.2130 - accuracy: 0.9225 - val_loss: 0.1103 - val_accuracy: 0.9032
# Epoch 8/100
# 3/3 [==============================] - 2s 630ms/step - loss: 0.1119 - accuracy: 0.9577 - val_loss: 0.0549 - val_accuracy: 1.0000
# Epoch 9/100
# 3/3 [==============================] - 2s 636ms/step - loss: 0.1023 - accuracy: 0.9718 - val_loss: 0.0346 - val_accuracy: 1.0000
# Epoch 10/100
# 3/3 [==============================] - 2s 628ms/step - loss: 0.0317 - accuracy: 0.9965 - val_loss: 0.0285 - val_accuracy: 1.0000
# Epoch 11/100
# 3/3 [==============================] - 2s 629ms/step - loss: 0.0428 - accuracy: 0.9789 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 12/100
# 3/3 [==============================] - 2s 630ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 4.5920e-04 - val_accuracy: 1.0000
# Epoch 13/100
# 3/3 [==============================] - 2s 627ms/step - loss: 0.0097 - accuracy: 0.9965 - val_loss: 5.0400e-04 - val_accuracy: 1.0000
# Epoch 14/100
# 3/3 [==============================] - 2s 631ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 3.7824e-04 - val_accuracy: 1.0000
# Epoch 15/100
# 3/3 [==============================] - 2s 632ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.7011e-04 - val_accuracy: 1.0000
# Epoch 16/100
# 3/3 [==============================] - 2s 629ms/step - loss: 0.0124 - accuracy: 0.9965 - val_loss: 2.9917e-05 - val_accuracy: 1.0000
# Epoch 17/100
# 3/3 [==============================] - 2s 633ms/step - loss: 3.1300e-04 - accuracy: 1.0000 - val_loss: 4.7414e-06 - val_accuracy: 1.0000
# Epoch 18/100
# 3/3 [==============================] - 2s 629ms/step - loss: 4.9488e-05 - accuracy: 1.0000 - val_loss: 8.5945e-06 - val_accuracy: 1.0000
# Epoch 19/100
# 3/3 [==============================] - 2s 628ms/step - loss: 4.7128e-04 - accuracy: 1.0000 - val_loss: 1.1075e-05 - val_accuracy: 1.0000
# Epoch 20/100
# 3/3 [==============================] - 2s 628ms/step - loss: 3.8488e-04 - accuracy: 1.0000 - val_loss: 3.0033e-06 - val_accuracy: 1.0000
# Epoch 21/100
# 3/3 [==============================] - 2s 634ms/step - loss: 1.0302e-04 - accuracy: 1.0000 - val_loss: 1.4920e-06 - val_accuracy: 1.0000
# Epoch 22/100
# 3/3 [==============================] - 2s 632ms/step - loss: 2.6765e-05 - accuracy: 1.0000 - val_loss: 1.5036e-06 - val_accuracy: 1.0000
# Epoch 23/100
# 3/3 [==============================] - 2s 631ms/step - loss: 8.7478e-06 - accuracy: 1.0000 - val_loss: 1.8304e-06 - val_accuracy: 1.0000
# Epoch 24/100
# 3/3 [==============================] - 2s 637ms/step - loss: 1.6110e-05 - accuracy: 1.0000 - val_loss: 2.1381e-06 - val_accuracy: 1.0000
# Epoch 25/100
# 3/3 [==============================] - 2s 629ms/step - loss: 2.0386e-05 - accuracy: 1.0000 - val_loss: 2.3342e-06 - val_accuracy: 1.0000
# Epoch 26/100
# 3/3 [==============================] - 2s 629ms/step - loss: 5.4427e-05 - accuracy: 1.0000 - val_loss: 2.2726e-06 - val_accuracy: 1.0000
# Epoch 27/100
# 3/3 [==============================] - 2s 630ms/step - loss: 8.5744e-06 - accuracy: 1.0000 - val_loss: 1.9150e-06 - val_accuracy: 1.0000
# Epoch 28/100
# 3/3 [==============================] - 2s 647ms/step - loss: 1.2419e-05 - accuracy: 1.0000 - val_loss: 1.6382e-06 - val_accuracy: 1.0000
# Epoch 29/100
# 3/3 [==============================] - 2s 628ms/step - loss: 8.2730e-06 - accuracy: 1.0000 - val_loss: 1.4305e-06 - val_accuracy: 1.0000
# Epoch 30/100
# 3/3 [==============================] - 2s 633ms/step - loss: 4.2143e-05 - accuracy: 1.0000 - val_loss: 1.2459e-06 - val_accuracy: 1.0000
# Epoch 31/100
# 3/3 [==============================] - 2s 631ms/step - loss: 4.6410e-06 - accuracy: 1.0000 - val_loss: 1.0960e-06 - val_accuracy: 1.0000
# Epoch 32/100
# 3/3 [==============================] - 2s 631ms/step - loss: 3.7629e-06 - accuracy: 1.0000 - val_loss: 1.0037e-06 - val_accuracy: 1.0000
# Epoch 33/100
# 3/3 [==============================] - 2s 630ms/step - loss: 1.1451e-05 - accuracy: 1.0000 - val_loss: 8.9983e-07 - val_accuracy: 1.0000
# Epoch 34/100
# 3/3 [==============================] - 2s 632ms/step - loss: 8.2772e-06 - accuracy: 1.0000 - val_loss: 8.3062e-07 - val_accuracy: 1.0000
# Epoch 35/100
# 3/3 [==============================] - 2s 629ms/step - loss: 4.1714e-06 - accuracy: 1.0000 - val_loss: 7.7293e-07 - val_accuracy: 1.0000
# Epoch 36/100
# 3/3 [==============================] - 2s 627ms/step - loss: 6.0255e-06 - accuracy: 1.0000 - val_loss: 7.3833e-07 - val_accuracy: 1.0000
# Epoch 37/100
# 3/3 [==============================] - 2s 627ms/step - loss: 5.0904e-06 - accuracy: 1.0000 - val_loss: 6.8064e-07 - val_accuracy: 1.0000
# Epoch 38/100
# 3/3 [==============================] - 2s 629ms/step - loss: 1.0147e-05 - accuracy: 1.0000 - val_loss: 6.4604e-07 - val_accuracy: 1.0000
# Epoch 39/100
# 3/3 [==============================] - 2s 631ms/step - loss: 4.0396e-06 - accuracy: 1.0000 - val_loss: 6.2296e-07 - val_accuracy: 1.0000
# Epoch 40/100
# 3/3 [==============================] - 2s 629ms/step - loss: 9.3216e-06 - accuracy: 1.0000 - val_loss: 5.8835e-07 - val_accuracy: 1.0000
# Epoch 41/100
# 3/3 [==============================] - 2s 627ms/step - loss: 3.1082e-06 - accuracy: 1.0000 - val_loss: 5.6528e-07 - val_accuracy: 1.0000
# Epoch 42/100
# 3/3 [==============================] - 2s 631ms/step - loss: 4.0206e-06 - accuracy: 1.0000 - val_loss: 5.4221e-07 - val_accuracy: 1.0000
# Epoch 43/100
# 3/3 [==============================] - 2s 633ms/step - loss: 3.3079e-06 - accuracy: 1.0000 - val_loss: 5.3067e-07 - val_accuracy: 1.0000
# Epoch 44/100
# 3/3 [==============================] - 2s 628ms/step - loss: 4.1125e-06 - accuracy: 1.0000 - val_loss: 5.1914e-07 - val_accuracy: 1.0000
# Epoch 45/100
# 3/3 [==============================] - 2s 630ms/step - loss: 4.6628e-06 - accuracy: 1.0000 - val_loss: 4.9606e-07 - val_accuracy: 1.0000
# Epoch 46/100
# 3/3 [==============================] - 2s 626ms/step - loss: 2.4270e-06 - accuracy: 1.0000 - val_loss: 4.8453e-07 - val_accuracy: 1.0000
# Epoch 47/100
# 3/3 [==============================] - 2s 630ms/step - loss: 3.9759e-06 - accuracy: 1.0000 - val_loss: 4.7299e-07 - val_accuracy: 1.0000
# Epoch 48/100
# 3/3 [==============================] - 2s 632ms/step - loss: 3.2580e-06 - accuracy: 1.0000 - val_loss: 4.6145e-07 - val_accuracy: 1.0000
# Epoch 49/100
# 3/3 [==============================] - 2s 632ms/step - loss: 2.6330e-06 - accuracy: 1.0000 - val_loss: 4.4992e-07 - val_accuracy: 1.0000
# Epoch 50/100
# 3/3 [==============================] - 2s 630ms/step - loss: 4.0813e-06 - accuracy: 1.0000 - val_loss: 4.3838e-07 - val_accuracy: 1.0000
# Epoch 51/100
# 3/3 [==============================] - 2s 627ms/step - loss: 2.6880e-06 - accuracy: 1.0000 - val_loss: 4.3838e-07 - val_accuracy: 1.0000
# Epoch 52/100
# 3/3 [==============================] - 2s 634ms/step - loss: 2.2532e-06 - accuracy: 1.0000 - val_loss: 4.2685e-07 - val_accuracy: 1.0000
# Epoch 53/100
# 3/3 [==============================] - 2s 627ms/step - loss: 4.0473e-06 - accuracy: 1.0000 - val_loss: 4.1531e-07 - val_accuracy: 1.0000
# Epoch 54/100
# 3/3 [==============================] - 2s 632ms/step - loss: 3.4619e-06 - accuracy: 1.0000 - val_loss: 4.0377e-07 - val_accuracy: 1.0000
# Epoch 55/100
# 3/3 [==============================] - 2s 626ms/step - loss: 2.2519e-06 - accuracy: 1.0000 - val_loss: 4.0377e-07 - val_accuracy: 1.0000
# Epoch 56/100
# 3/3 [==============================] - 2s 633ms/step - loss: 6.6909e-06 - accuracy: 1.0000 - val_loss: 3.8070e-07 - val_accuracy: 1.0000
# Epoch 57/100
# 3/3 [==============================] - 2s 631ms/step - loss: 4.6930e-06 - accuracy: 1.0000 - val_loss: 3.6916e-07 - val_accuracy: 1.0000
# Epoch 58/100
# 3/3 [==============================] - 2s 628ms/step - loss: 2.4932e-06 - accuracy: 1.0000 - val_loss: 3.5763e-07 - val_accuracy: 1.0000
# Epoch 59/100
# 3/3 [==============================] - 2s 634ms/step - loss: 2.2523e-06 - accuracy: 1.0000 - val_loss: 3.4609e-07 - val_accuracy: 1.0000
# Epoch 60/100
# 3/3 [==============================] - 2s 624ms/step - loss: 6.2228e-06 - accuracy: 1.0000 - val_loss: 3.3455e-07 - val_accuracy: 1.0000
# Epoch 61/100
# 3/3 [==============================] - 2s 630ms/step - loss: 2.4118e-06 - accuracy: 1.0000 - val_loss: 3.2302e-07 - val_accuracy: 1.0000
# Epoch 62/100
# 3/3 [==============================] - 2s 630ms/step - loss: 3.4586e-06 - accuracy: 1.0000 - val_loss: 3.1148e-07 - val_accuracy: 1.0000
# Epoch 63/100
# 3/3 [==============================] - 2s 646ms/step - loss: 5.5602e-06 - accuracy: 1.0000 - val_loss: 2.9995e-07 - val_accuracy: 1.0000
# Epoch 64/100
# 3/3 [==============================] - 2s 632ms/step - loss: 5.1424e-06 - accuracy: 1.0000 - val_loss: 2.8841e-07 - val_accuracy: 1.0000
# Epoch 65/100
# 3/3 [==============================] - 2s 632ms/step - loss: 1.9954e-06 - accuracy: 1.0000 - val_loss: 2.6534e-07 - val_accuracy: 1.0000
# Epoch 66/100
# 3/3 [==============================] - 2s 628ms/step - loss: 1.9199e-06 - accuracy: 1.0000 - val_loss: 2.5380e-07 - val_accuracy: 1.0000
# Epoch 67/100
# 3/3 [==============================] - 2s 635ms/step - loss: 2.5948e-06 - accuracy: 1.0000 - val_loss: 2.4226e-07 - val_accuracy: 1.0000
# Epoch 68/100
# 3/3 [==============================] - 2s 629ms/step - loss: 4.5969e-06 - accuracy: 1.0000 - val_loss: 2.3073e-07 - val_accuracy: 1.0000
# Epoch 69/100
# 3/3 [==============================] - 2s 630ms/step - loss: 2.2466e-05 - accuracy: 1.0000 - val_loss: 2.1919e-07 - val_accuracy: 1.0000
# Epoch 70/100
# 3/3 [==============================] - 2s 633ms/step - loss: 2.3976e-06 - accuracy: 1.0000 - val_loss: 1.9612e-07 - val_accuracy: 1.0000
# Epoch 71/100
# 3/3 [==============================] - 2s 632ms/step - loss: 2.7530e-06 - accuracy: 1.0000 - val_loss: 1.8458e-07 - val_accuracy: 1.0000
# Epoch 72/100
# 3/3 [==============================] - 2s 635ms/step - loss: 1.9182e-06 - accuracy: 1.0000 - val_loss: 1.7305e-07 - val_accuracy: 1.0000
# Epoch 73/100
# 3/3 [==============================] - 2s 632ms/step - loss: 1.6920e-06 - accuracy: 1.0000 - val_loss: 1.6151e-07 - val_accuracy: 1.0000
# Epoch 74/100
# 3/3 [==============================] - 2s 634ms/step - loss: 2.1445e-06 - accuracy: 1.0000 - val_loss: 1.6151e-07 - val_accuracy: 1.0000
# Epoch 75/100
# 3/3 [==============================] - 2s 626ms/step - loss: 1.6542e-06 - accuracy: 1.0000 - val_loss: 1.4997e-07 - val_accuracy: 1.0000
# Epoch 76/100
# 3/3 [==============================] - 2s 629ms/step - loss: 1.5073e-06 - accuracy: 1.0000 - val_loss: 1.4997e-07 - val_accuracy: 1.0000
# Epoch 77/100
# 3/3 [==============================] - 2s 630ms/step - loss: 1.0929e-05 - accuracy: 1.0000 - val_loss: 1.3844e-07 - val_accuracy: 1.0000
# Epoch 78/100
# 3/3 [==============================] - 2s 631ms/step - loss: 2.0857e-06 - accuracy: 1.0000 - val_loss: 1.0383e-07 - val_accuracy: 1.0000
# Epoch 79/100
# 3/3 [==============================] - 2s 646ms/step - loss: 3.4250e-06 - accuracy: 1.0000 - val_loss: 1.0383e-07 - val_accuracy: 1.0000
# Epoch 80/100
# 3/3 [==============================] - 2s 636ms/step - loss: 3.6793e-06 - accuracy: 1.0000 - val_loss: 9.2291e-08 - val_accuracy: 1.0000
# Epoch 81/100
# 3/3 [==============================] - 2s 630ms/step - loss: 4.6469e-06 - accuracy: 1.0000 - val_loss: 8.0755e-08 - val_accuracy: 1.0000
# Epoch 82/100
# 3/3 [==============================] - 2s 625ms/step - loss: 3.5312e-06 - accuracy: 1.0000 - val_loss: 8.0755e-08 - val_accuracy: 1.0000
# Epoch 83/100
# 3/3 [==============================] - 2s 628ms/step - loss: 2.6221e-06 - accuracy: 1.0000 - val_loss: 8.0755e-08 - val_accuracy: 1.0000
# Epoch 84/100
# 3/3 [==============================] - 2s 628ms/step - loss: 2.5352e-06 - accuracy: 1.0000 - val_loss: 8.0755e-08 - val_accuracy: 1.0000
# Epoch 85/100
# 3/3 [==============================] - 2s 632ms/step - loss: 2.3455e-06 - accuracy: 1.0000 - val_loss: 8.0755e-08 - val_accuracy: 1.0000
# Epoch 86/100
# 3/3 [==============================] - 2s 633ms/step - loss: 3.4250e-06 - accuracy: 1.0000 - val_loss: 6.9218e-08 - val_accuracy: 1.0000
# Epoch 87/100
# 3/3 [==============================] - 2s 626ms/step - loss: 1.3574e-06 - accuracy: 1.0000 - val_loss: 6.9218e-08 - val_accuracy: 1.0000
# Epoch 88/100
# 3/3 [==============================] - 2s 630ms/step - loss: 2.1692e-06 - accuracy: 1.0000 - val_loss: 6.9218e-08 - val_accuracy: 1.0000
# Epoch 89/100
# 3/3 [==============================] - 2s 634ms/step - loss: 2.0878e-06 - accuracy: 1.0000 - val_loss: 6.9218e-08 - val_accuracy: 1.0000
# Epoch 90/100
# 3/3 [==============================] - 2s 630ms/step - loss: 3.7223e-06 - accuracy: 1.0000 - val_loss: 6.9218e-08 - val_accuracy: 1.0000
# Epoch 91/100
# 3/3 [==============================] - 2s 631ms/step - loss: 2.1842e-06 - accuracy: 1.0000 - val_loss: 6.9218e-08 - val_accuracy: 1.0000
# Epoch 92/100
# 3/3 [==============================] - 2s 627ms/step - loss: 2.1054e-06 - accuracy: 1.0000 - val_loss: 6.9218e-08 - val_accuracy: 1.0000
# Epoch 93/100
# 3/3 [==============================] - 2s 630ms/step - loss: 1.5279e-06 - accuracy: 1.0000 - val_loss: 6.9218e-08 - val_accuracy: 1.0000
# Epoch 94/100
# 3/3 [==============================] - 2s 625ms/step - loss: 3.2343e-06 - accuracy: 1.0000 - val_loss: 6.9218e-08 - val_accuracy: 1.0000
# Epoch 95/100
# 3/3 [==============================] - 2s 632ms/step - loss: 2.2660e-06 - accuracy: 1.0000 - val_loss: 6.9218e-08 - val_accuracy: 1.0000
# Epoch 96/100
# 3/3 [==============================] - 2s 629ms/step - loss: 8.2564e-07 - accuracy: 1.0000 - val_loss: 6.9218e-08 - val_accuracy: 1.0000

# %%
SAMPLES_TO_DISPLAY = 1

test_ds = paths_and_labels_to_dataset(valid_audio_paths, valid_labels)
test_ds = test_ds.shuffle(buffer_size=BATCH_SIZE * 8, seed=SHUFFLE_SEED).batch(
    BATCH_SIZE
)

test_ds = test_ds.map(lambda x, y: (add_noise(x, noises, scale=SCALE), y))

for audios, labels in test_ds.take(1):
    # Get the signal FFT
    ffts = audio_to_fft(audios)
    # Predict
    y_pred = model.predict(ffts)
    # Take random samples
    rnd = np.random.randint(0, 30, SAMPLES_TO_DISPLAY)
    print(rnd)
    print(y_pred[rnd])
    audios = audios.numpy()[rnd, :, :]
    labels = labels.numpy()[rnd]
    y_pred = np.argmax(y_pred, axis=-1)[rnd]
    print(y_pred)

    for index in range(SAMPLES_TO_DISPLAY):
        # For every sample, print the true and predicted label
        # as well as run the voice with the noise
        print(
            "Speaker: {} - Predicted: {}".format(
                class_names[labels[index]],
                class_names[y_pred[index]],
            )
        )
        display(Audio(audios[index, :, :].squeeze(), rate=SAMPLING_RATE))
        
        for i in rnd:
            np.savetxt("ffts_"+class_names[labels[index]]+".txt", np.array(ffts[i,:,:]))
# Out:
# [19]
# [[1.2138806e-06 9.9999881e-01]]
# [1]
# Speaker: Yuhan - Predicted: Yuhan
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
keras_file = "user_speech.h5"
tf.keras.models.save_model(model, keras_file)
converter = lite.TFLiteConverter.from_keras_model(model)
tfmodel = converter.convert()
with open("user_speech.tflite", "wb") as f:
    f.write(tfmodel)
# Out:
# WARNING:tensorflow:From C:\Users\Hubert\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\Hubert\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: C:\Users\Hubert\AppData\Local\Temp\tmpvvy8ng9d\assets
